# %% [markdown]
#  ## Creación de Figuras Simples

# %%
import matplotlib.pyplot as plt

# %%
eje_x1 = ['A','B','C','D','E']
datos1 =[23,21,28,30,20]
datos2=[12,15,23,30,40]
plt.plot(eje_x1,datos1)
plt.show()
plt.plot(eje_x1,datos1)
plt.plot(eje_x1,datos2)
plt.show()

# %%
import numpy as np
años = ['2010','2011','2012','2013','2014','2015','2016','2017']
nivel1 = np.random.rand(8)*100
nivel2 = np.random.rand(8)*200+100
nivel3 = np.random.rand(8)*300+200
nivel4 = np.random.rand(8)*400+300
nivel5 = np.random.rand(8)*500+400

# %%
plt.plot(años,nivel1, label = "Nivel 1", color = 'black', marker='.')
plt.plot(años,nivel2, label = 'Nivel 2', linestyle = '--')
plt.plot(años,nivel3, label = 'Nivel 3')
plt.plot(años,nivel4, label = 'Nivel 4')
plt.plot(años,nivel5, label = 'Nivel 5', marker = '>')
plt.legend(loc = 'upper right')
plt.title('Examen de Certificación')
plt.xlabel('Años en que se ha realizado el examen')
plt.ylabel('Notas')
plt.yticks(np.arange(0,1000,100))
plt.show()

# %% [markdown]
# ## Generación de Datos Aleatorios y Contexto de Ejercicios

# %% [markdown]
# ##  Personalización de Figuras

# %% [markdown]
# ##  Gráficas de Barras Verticales

# %%
eje_x = ['A','B','C','D','E','F','G','H']
plt.bar(eje_x, nivel1, color = 'red')
plt.yticks(np.arange(0,150,20))
plt.show()

plt.bar(eje_x, nivel3)
plt.bar(eje_x, nivel2)
plt.bar(eje_x, nivel1)
plt.show()

plt.bar(eje_x, nivel5, width = 1/5)
plt.bar(eje_x, nivel4, width = 1/5)
plt.bar(eje_x, nivel3, width = 1/5)
plt.bar(eje_x, nivel2, width = 1/5)
plt.bar(eje_x, nivel1, width = 1/5)
plt.show()

# %% [markdown]
# ## Gráficas de Barras Horizontales

# %% [markdown]
# ##  Gráficas de Barras Apiladas

# %% [markdown]
# ##  Gráficas de Dispersión

# %%
plt.scatter(eje_x,nivel1)
plt.scatter(eje_x,nivel2)
plt.scatter(eje_x,nivel3)
plt.scatter(eje_x,nivel5)
plt.scatter(eje_x,nivel4)
plt.show()

# %% [markdown]
# ##  Gráficas de Pie

# %%
plt.pie(nivel1)
plt.show()

plt.pie(nivel1, labels = ['A','B','C','D','E','F','G','H'])
plt.show()

# %%
plt.boxplot(nivel1)
plt.show()

# %% [markdown]
# # ***Libreria  Seaborn***
